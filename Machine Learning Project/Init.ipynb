# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 17.2 MB/s eta 0:00:00
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.7 MB/s eta 0:00:00
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting yellowbrick==1.5
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 28.2 MB/s eta 0:00:00
# Collecting ace_tools==0.0
#   Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Collecting kneed==0.8.5
#   Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Requirement already satisfied: cycler>=0.10.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: scipy>=1.0.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.9.3)
# Requirement already satisfied: numpy>=1.16.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.25.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 4)) (3.6.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (3.6.0)
# Collecting scikit-learn>=1.0.0
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 68.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.2 in /root/venv/lib/python3.9/site-packages (from mlxtend->-r ./requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from missingno->-r ./requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 4)) (1.17.0)
# Installing collected packages: ace_tools, scikit-learn, kneed, yellowbrick, mlxtend, imbalanced-learn, missingno
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
# Successfully installed ace_tools-0.0 imbalanced-learn-0.12.4 kneed-0.8.5 missingno-0.5.2 mlxtend-0.23.4 scikit-learn-1.6.1 yellowbrick-1.5
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
